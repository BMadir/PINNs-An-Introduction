# %% [markdown]
# # Ritz-PINNs
# @Bahae-Eddine Madir

# %%
import sys
sys.path.insert(1, '../Utilities/')

# %%
import torch
import numpy as np
from tqdm.notebook import tqdm

# %%
from sampling import *
from AutoDiff import AG_grad

from torch.func import vmap
from quadrature import GaussLegendre

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
#rc('text', usetex=True)
rc('xtick', direction='in', top=True)
rc('ytick', direction='in', right=True)

# %%
import scienceplots
plt.style.use(['science', 'ieee'])

# %%
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif':'Times New Roman'})
rc('legend', **{'frameon': True, 'fancybox': False, 'edgecolor': "k", 'framealpha':1, 'fontsize': 8, 'handlelength':1.25})

# %%
import matplotlib.ticker as ticker
def fmt(x, pos):
    a, b = '{:.1e}'.format(x).split('e')
    b = int(b)
    return r'${}$e${}$'.format(a, b)

# %%
from matplotlib.patches import Rectangle

# %%
save = True
savefile = "./outputs/ritz/"

# %%
torch.manual_seed(1234)
class ff(torch.nn.Module):
    def __init__(self, n_neurones):
        super().__init__()

        self.l1 = torch.nn.Linear(2, n_neurones)
        self.act = torch.nn.Tanh()
        self.l2 = torch.nn.Linear(n_neurones, 1)

        self.params_dict = dict(self.named_parameters())
        
    def forward(self, *inputs):
        inputs = torch.cat(inputs, 1)
        outputs = self.act(self.l1(inputs))
        return self.l2(outputs)

# %%
device = torch.device("cpu")

# %%
net = ff(15).to(device)

# %%
#model = net
model = lambda x, y: x* (x-1)* y* (y-1)* net(x, y)

# %%
u_ref = lambda x, y: torch.sin(torch.pi* x)* torch.sin(torch.pi* y) + (1/2)* torch.sin(3* torch.pi* x)* torch.sin(2* torch.pi* y)
f = lambda x, y: torch.pi**2* (2* torch.sin(torch.pi* x) + 13* torch.sin(3* torch.pi* x)* torch.cos(torch.pi* y))* torch.sin(torch.pi* y)

# %% [markdown]
# ## Elements

# %%
def elements_fn(x, y):
    nx = len(x)
    ny = len(y)
    elements = []
    
    for i in range(nx):
        if x[i:i+2].numel()<2:
            continue
        for j in range(ny):
            if y[j:j+2].numel()<2:
                continue
            else:
                element = [x[i:i+2], y[j:j+2]]
                elements.append(element)

    return elements

# %%
nx = 4
ny = 4
x = torch.linspace(0, 1, nx+1).to(device)
y = torch.linspace(0, 1, ny+1).to(device)
elements = elements_fn(x, y)

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4))

for e in elements:
    mi_x, mi_y = min(e[0].cpu()), min(e[1].cpu())
    ma_x, ma_y = max(e[0].cpu()), max(e[1].cpu())
    ax.add_patch(Rectangle((mi_x, mi_y), ma_x-mi_x, ma_y-mi_y, fill=False, lw=.5))


ax.set_xticks([0, 0.25, 0.5, .75, 1])
ax.set_yticks([0.25, 0.5, .75, 1])

ax.set_ylabel("$y$", fontsize=14)
ax.set_xlabel("$x$", fontsize=14)

if save:
    plt.savefig(savefile + 'elemnts.pdf', bbox_inches ='tight')

plt.show()

# %% [markdown]
# ## Integration

# %%
# from I_hat to I:
def scale_1D(x, I):
    A = (I[-1] - I[0])/2
    B = (I[-1] + I[0])/2
    return A * x + B, A

# from I to I_hat:
def inv_scale_1D(x):
    A = (x[-1] - x[0])/2
    B = (x[-1] + x[0])/2
    return (x - B)/A
    
# from K_hat to K
def scale(x, y, K):
    x, Jx = scale_1D(x, K[0])
    y, Jy = scale_1D(y, K[1])
    return x, y, Jx, Jy

# %%
# Quadrature:
q_ord = 10

(x_q, y_q), w_q = GaussLegendre().Quad2d(q_ord)

x_q = torch.Tensor(x_q).flatten()
y_q = torch.Tensor(y_q).flatten()
w_q = torch.Tensor(w_q)

# %%
quad = w_q.to(device), x_q.reshape(-1, 1).to(device), y_q.reshape(-1, 1).to(device)

# %%
def int_K(K, quad, f=lambda *args: torch.zeros_like(args[0])):
    """
    the test_fn are computed in K_hat. If test_fn.shape is (n, m) then grad_test_fn.shape is (n, 2, m)
    """
    # quadrature weights and nodes
    w, x, y = quad
    qx, qy = w.shape # order
    
    # scale x, y to K, and compute the Jacobien and rescale the gradient
    x, y, Jx, Jy = scale(x, y, K)
    J = Jx* Jy
    
    # compute grad_u = (u_x, u_y)
    if not x.requires_grad:
        x.requires_grad_()
    if not y.requires_grad:
        y.requires_grad_()
    
    u = model(x, y)
    grad_u = torch.stack(AG_grad(u, (x, y))).reshape(2, -1)
    _integrand = 0.5* (grad_u**2).sum(0) - f(x, y).flatten() * u.flatten()
    _int = torch.einsum('ji, ij->', w, J *_integrand.reshape(qx, qy))
    
    return _int

# %% [raw]
# K = [[0, 1], [0, 1]]
# int_K(K, quad, f)

# %% [markdown]
# ## Losses

# %%
def res_loss():
    loss = 0.
    for K in elements:
        _int = int_K(K, quad, f) 
        loss += _int
    return loss

# %% [raw]
# def bdry_loss():
#     u = net(x_bdry, y_bdry)
#     return (u**2).mean()

# %%
def err_l2(ref, pred):
    return np.linalg.norm(ref - pred, 2) / np.linalg.norm(ref, 2)

# %% [markdown]
# ## Data

# %% [raw]
# xl, xu = 0., 1.
# yl, yu = 0., 1.
#
# zeros = lambda *args: np.zeros_like(args[0])

# %% [raw]
# ### Boundary
# n_bdry = 51* 4
#
# bc1_sampler = Sampler([xl, yl], [xl, yu], zeros) # at xl
# bc2_sampler = Sampler([xu, yl], [xu, yu], zeros) # at xu
# bc3_sampler = Sampler([xl, yl], [xu, yl], zeros) # at yl
# bc4_sampler = Sampler([xl, yu], [xu, yu], zeros) # at yu
# bcs_sampler = Join_samplers([bc1_sampler, bc2_sampler, bc3_sampler, bc4_sampler])
#
# x_bdry, y_bdry, _ = bcs_sampler.sample(n_bdry, device=device)

# %% [markdown]
# ## Optimization

# %% [raw]
# w_b = 1000

# %%
losses = {'data':[], 'physics':[], 'total':[], 'l2':[]}

def closure():
    global l_data, l_phys
    net.zero_grad()

    #l_data = bdry_loss()
    l_phys = res_loss()
    loss = l_phys # + w_b * l_data
    
    loss.backward()
    
    return loss

# %%
optim = torch.optim.LBFGS(
    net.parameters(), 
    line_search_fn="strong_wolfe"
)
n_epochs = 26

# %%
nx = 100
x = torch.linspace(0, 1, nx).to(device)
x, y = torch.meshgrid(x, x, indexing="xy")
pred = model(x.reshape(-1, 1), y.reshape(-1, 1)).detach().reshape(nx, nx).cpu()
x = x.cpu()
y = y.cpu()

ref = u_ref(x, y)

# %%
# %%time

for _ in tqdm(range(n_epochs)) :
    
    loss = optim.step(closure)
    
    # save
    #losses['data'].append(l_data.item())
    losses['physics'].append(l_phys.item())
    losses['total'].append(loss.item())

    pred = model(x.reshape(-1, 1), y.reshape(-1, 1)).detach().reshape(nx, nx).cpu()
    losses['l2'].append(err_l2(ref, pred))
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# CPU times: user 6.55 s, sys: 45.7 ms, total: 6.6 s
# Wall time: 4.6 s

# %% [markdown]
# ## Pred

# %% [raw]
# # pred
# fig, ax = plt.subplots(1, 1)
#
# cb = ax.contourf(x, y, pred, cmap='coolwarm', levels=15)
# fig.colorbar(cb, shrink=.8, aspect=12)
#
# for e in elements:
#     mi_x, mi_y = min(e[0].cpu()), min(e[1].cpu())
#     ma_x, ma_y = max(e[0].cpu()), max(e[1].cpu())
#     ax.add_patch(Rectangle((mi_x, mi_y), ma_x-mi_x, ma_y-mi_y, fill=False, lw=.5))
#     _x_res, _y_res, _, _ = scale(x_q.to(device), y_q.to(device), e)
#     plt.scatter(_x_res.cpu(), _y_res.cpu(), s=.5, alpha=.3, c='k', label='$(x_r, y_r)$')
#
# #plt.scatter(x_bdry, y_bdry, c='r', marker='x', s=4)
#
# ax.set_title(r'$\widehat{u}$', pad=10, fontsize=12)
# ax.set_ylabel("$y$", fontsize=14)
# ax.set_xlabel("$x$", fontsize=14)
#
# #plt.legend(loc='upper right')
# if save:
#     plt.savefig(savefile + 'pred.pdf', bbox_inches ='tight')
#
# plt.show()

# %% [raw]
# # ref
# fig, ax = plt.subplots(1, 1)
#
# cb = ax.contourf(x, y, ref, cmap='coolwarm', levels=15)
# fig.colorbar(cb, shrink=.8, aspect=12)
#
# ax.set_title(r'$u$', pad=10, fontsize=12)
# ax.set_ylabel("$y$", fontsize=14)
# ax.set_xlabel("$x$", fontsize=14)
#
# if save:
#     plt.savefig(savefile + 'ref.pdf', bbox_inches ='tight')
# plt.show()

# %% [raw]
# # error
# fig, ax = plt.subplots(1, 1)
# ctf = ax.contourf(x, y, torch.abs(ref-pred), cmap='coolwarm', levels=4)
# cb = fig.colorbar(ctf, shrink=.8, aspect=12, format=ticker.FuncFormatter(fmt))
#
# ax.set_title(r'$ |\widehat{u} - u| $ ', pad=10, fontsize=12)
# ax.set_ylabel("$y$", fontsize=12)
# ax.set_xlabel("$x$", fontsize=12)
#
# ax.set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
# ax.set_yticks([0.2, 0.4, 0.6, 0.8, 1])
#
# """
# for e in elements:
#     mi_x, mi_y = min(e[0].cpu()), min(e[1].cpu())
#     ma_x, ma_y = max(e[0].cpu()), max(e[1].cpu())
#     ax.add_patch(Rectangle((mi_x, mi_y), ma_x-mi_x, ma_y-mi_y,fill=False, lw=.2))
# """
# if save:
#     plt.savefig(savefile + 'abs_error.pdf', bbox_inches ='tight')
#
# plt.show()

# %%
print(f'Rel. L2 error : {err_l2(ref, pred) :.3e}')
# Out:
# Rel. L2 error : 1.803e-03

# %%
galerkin = np.loadtxt('./outputs/galerkin/galerkin')
l2_galerkin = np.loadtxt('./outputs/galerkin/l2_galerkin')

# %%
# Pred
fig, ax = plt.subplots(1, 1)

ax.grid(True)
ax.plot(np.diag(x), np.diag(ref), '--', alpha=.6, label='$u(x, x)$')

ax.plot(np.diag(x), galerkin[:, 1], '^', markevery=3, markersize=4, markerfacecolor='none', alpha=.7, label='Galerkin')
ax.plot(np.diag(x), np.diag(pred), 's', markevery=3, markersize=3, markerfacecolor='none', alpha=.5, label='Energy')


#ax.set_title(r'(a).', pad=10, fontsize=12)
#ax.set_ylabel("$y$", fontsize=14)
ax.set_xlabel("$x$", fontsize=14)

plt.legend().get_frame().set_linewidth(0.25)

if save:
    plt.savefig(savefile + 'pred_diag.pdf', bbox_inches ='tight')
plt.show()

# %%
epochs = range(n_epochs)

# %%
fig, axs = plt.subplots(1, 1)

axs.grid(True)
#axs.set_yscale('log')
axs.set_xlabel('Epoch', fontsize=12)
axs.plot(epochs, losses['total'], "-", alpha=.7, label='$\mathcal{E}$')

#axs.set_xticks(epochs[::25])
axs.legend().get_frame().set_linewidth(0.25)

if save:
    plt.savefig(savefile + 'losses.pdf', bbox_inches ='tight')
plt.show()

# %%
fig, axs = plt.subplots(1, 1)

axs.grid(True, which='both')
axs.set_yscale('log')
axs.set_xlabel('Epoch', fontsize=12)

axs.plot(l2_galerkin[:, 0], l2_galerkin[:, 1], "^--", color='red', markersize=4, markevery=5, markerfacecolor='none', alpha=.7, label='Galerkin')
axs.plot(epochs, losses['l2'], "s--", color='blue', markersize=4, markevery=5, markerfacecolor='none', alpha=.7, label='Energy')


#axs.set_xticks(epochs)
axs.legend().get_frame().set_linewidth(0.25)

if save:
    plt.savefig(savefile + 'l2_error.pdf', bbox_inches ='tight')
plt.show()
